# %%
import pandas as pd
import numpy as np
 
 

url = "https://raw.githubusercontent.com/andreamoranamao/portafolio-mineria-datos/refs/heads/main/googleplaystore.csv"
df = pd.read_csv(url)

df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# ### Pregunta A:
# Ejecuten df.isnull().sum(). Identificarán que la columna Rating tiene casi 1,500 valores nulos, mientras que Type y Android Ver tienen solo 1 o 2. ¿Por qué es arquitectónicamente seguro eliminar las filas donde falta Android Ver, pero sería un error fatal eliminar las filas donde falta Rating?

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ### Respuesta A
# En este caso seria fatal eliminar la fila rating en vez de la android ver porque no son tantas las de andoid ver en comparacion si quitas la de rating ya no se tomara en cuenta a la hora de interpretar el dataset.

# %% [markdown]
# ### Pregunta B:
# Escriban la instrucción exacta usando dropna() pasándole el parámetro subset=['Android Ver', 'Type'] para eliminar únicamente las 3 filas que tienen esos nulos. Verifiquen que el total de registros en el DataFrame apenas disminuyó.

# %%
df = df.dropna(subset=['Android Ver', 'Type'])

# %%
df.shape
# Out:
# (10837, 13)

# %% [markdown]
# ### Respuesta B:
#
# Se eliminaron las filas que tenian valores nulos en la fila Android Ver o Type por eso disminuyo el total de registros.

# %% [markdown]
# ### Pregunta C:
# Rellenar los 1,500 nulos de Rating con el promedio global es un error, ya que las apps de la categoría FAMILY (Familia) no se califican igual que las de DATING (Citas). Utilizando la lógica de la semana pasada, escriban un bloque combinando .groupby('Category') y .transform() para rellenar los NaN de la columna Rating usando la mediana de su propia categoría.

# %%
df['Rating'] = df['Rating'].fillna(
    df.groupby('Category')['Rating'].transform('median')
)

df['Rating'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Respuesta C
# se utilizo la mediana de cada categoria para rellenar los valores faltantes de Rating

# %% [markdown]
# ### Pregunta D:
# Revisen la columna Size (Tamaño de la app). Notarán que no tiene nulos matemáticos (NaN), pero muchas filas dicen "Varies with device". Para un modelo matemático, ese texto es basura indigerible. Escriban una instrucción usando df['Size'].replace(...) para convertir exactamente esa frase de texto en un nulo matemático real usando np.nan de NumPy. ¿Por qué es mejor convertirlo a NaN en esta etapa en lugar de ponerle un tamaño falso como "0 MB"?

# %%
df['Size'] = df['Size'].replace('Varies with device', np.nan)

df['Size'].isnull().sum()
# Out:
# np.int64(1694)

# %% [markdown]
# ### Respeusta D
# es mejor ponerlo como nan porque no sabemos el tamano de la app, si se pusiera un valor como 0 no seria verdadero y podria crear un sesgo.

# %%
df['Installs'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Installs'].mean()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)
#    6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)
#   12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria_datos/lib/python3.10/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '10,000+500,000+5,000,000+50,000,000+100,000+50,000+50,000+1,000,000+1,000,000+10,000+1,000,000+1,000,000+10,000,000+100,000+100,000+5,000+500,000+10,000+5,000,000+10,000,000+100,000+100,000+500,000+100,000+50,000+10,000+500,000+100,000+10,000+100,000+100,000+50,000+100,000+100,000+10,000+100,000+500,000+5,000,000+10,000+500,000+10,000+100,000+10,000,000+100,000+10,000+10,000,000+100,000+100,000+100,000+100,000+1,000,000+100,000+1,000,000+100,000+100,000+100,000+50,000+100,000+100,000+100,000+10,000+100,000+1,000,000+100,000+100,000+10,000+50,000+5,000,000+100,000+5,000,000+5,000,000+500,000+10,000,000+100,000+500,000+50,000+100,000+1,000,000+100,000+1,000,000+50,000+1,000,000+500,000+100,000+1,000,000+1,000,000+100,