# %%
import pandas as pd
 
 
url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/titanic.csv"
df = pd.read_csv(url)

print(df.head())
print(df.describe())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# Pregunta A: Observen la columna Fare (Tarifa del boleto). ¿Cuál es la diferencia matemática entre el percentil 75% (el tercer cuartil) y el valor Máximo (max)? Como ingenieros de software, ¿qué les dice esta enorme dispersión estadística sobre la homogeneidad de los precios que se cobraron en el barco?
#
#     La diferencia entre el tercer cuartil y el valor maximo es bastante amplia ya que la maxima es de 512 y la del tercer cuartil es de 31, lo cual nos da una diferencia de 481. Esta gran diferencia entre los datos nos dice que había una gran dispersión en los precios de los boletos, por lo que no eran homogéneos. Algunos pasajeros pagaron precios mucho más altos que la mayoría.
#
# Pregunta B: Revisen la fila count (conteo total de registros válidos) de las distintas columnas en el resultado de su .describe(). Comparen el conteo de la columna PassengerId con el conteo de la columna Age. ¿Qué anomalía de base de datos acaban de descubrir?
#
#     Viendo la columna PassengerId comparada a la columa de edad, no tiene congruencia. La columna de PassengerId tiene como valor de 891 en la fila count. A comparacion la edad tiene en count 714 cuando deberian de ser todas iguales. Esto quiere decir que hay valores faltantes que no se registraron o se tomaron como nulos lo cual crea un problema.
#
# Pregunta C: El algoritmo que construirán al final del semestre requiere que todos los pasajeros tengan un valor numérico en la columna Age para poder compilar. Sabiendo lo que acaban de descubrir en la Pregunta B, propongan al menos dos estrategias a nivel de base de datos o de programación para resolver este problema antes de alimentar a la IA.
#
#     Una estrategia sería reemplazar los valores faltantes de Age por la media. De esta manera, todos los registros tendrían un valor numérico y se podrían utilizar para entrenar el algoritmo.
#
#     También se podría estimar la edad faltante utilizando otras columnas, la clase del pasajero o incluso el título que aparece en el nombre. Esto permitiría asignar una edad aproximada basándose en las características de pasajeros similares.
